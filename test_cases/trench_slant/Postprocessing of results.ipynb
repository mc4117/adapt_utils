# %%
import pandas as pd
results_01 = pd.read_excel('results.xlsx', sheet_name = '0.1')
results_02 = pd.read_excel('results.xlsx', sheet_name = '0.2')
results_04 = pd.read_excel('results.xlsx', sheet_name = '0.4')
results_08 = pd.read_excel('results.xlsx', sheet_name = '0.8')
results_16 = pd.read_excel('results.xlsx', sheet_name = '1.6')

# %%
import pylab as plt
#plt.plot(results_16[results_16['beta']==0]['alpha'], results_16[results_16['beta']==0]['error'])
plt.plot(results_16[results_16['beta']==0.25]['alpha'], results_16[results_16['beta']==0.25]['error'], color = 'blue', label = r'$\Delta x = 0.125m; \beta = 0.25$')
plt.plot(results_16[results_16['beta']==0.5]['alpha'], results_16[results_16['beta']==0.5]['error'], color = 'orange', label = r'$\Delta x = 0.125m; \beta = 0.5$')
plt.plot(results_16[results_16['beta']==0.75]['alpha'], results_16[results_16['beta']==0.75]['error'], color = 'green', label = r'$\Delta x = 0.125m; \beta = 0.75$')
plt.plot(results_16[results_16['beta']==1.0]['alpha'], results_16[results_16['beta']==1.0]['error'], color = 'red', label = r'$\Delta x = 0.125m; \beta = 1$')


#plt.plot(results_08[results_08['beta']==0]['alpha'], results_08[results_08['beta']==0]['error'])
plt.plot(results_08[results_08['beta']==0.25]['alpha'], results_08[results_08['beta']==0.25]['error'], '--', color = 'blue', label = r'$\Delta x = 0.25m; \beta = 0.25$')
plt.plot(results_08[results_08['beta']==0.5]['alpha'], results_08[results_08['beta']==0.5]['error'], '--', color = 'orange', label = r'$\Delta x = 0.25m; \beta = 0.5$')
plt.plot(results_08[results_08['beta']==0.75]['alpha'], results_08[results_08['beta']==0.75]['error'], '--', color = 'green', label = r'$\Delta x = 0.25m; \beta = 0.75$')
plt.plot(results_08[results_08['beta']==1.0]['alpha'], results_08[results_08['beta']==1.0]['error'],'--', color = 'red', label = r'$\Delta x = 0.25m; \beta = 1$')
plt.legend(ncol = 2, loc = 10)
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.show()

plt.plot(results_04[results_04['beta']==0]['alpha'], results_04[results_04['beta']==0]['error'], color = 'black', label = r'$\Delta x = 0.5m; \beta = 0$')
plt.plot(results_04[results_04['beta']==0.25]['alpha'], results_04[results_04['beta']==0.25]['error'], color = 'blue', label = r'$\Delta x = 0.5m; \beta = 0.25$')
plt.plot(results_04[results_04['beta']==0.5]['alpha'], results_04[results_04['beta']==0.5]['error'], color = 'orange', label = r'$\Delta x = 0.5m; \beta = 0.5$')
plt.plot(results_04[results_04['beta']==0.75]['alpha'], results_04[results_04['beta']==0.75]['error'], color = 'green', label = r'$\Delta x = 0.5m; \beta = 0.75$')
plt.plot(results_04[results_04['beta']==1.0]['alpha'], results_04[results_04['beta']==1.0]['error'], color = 'red', label = r'$\Delta x = 0.5m; \beta = 1$')
plt.legend(loc = 1)
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.show()

# %%
from matplotlib import cm
import numpy as np

start = 0.0
stop = 1.0
number_of_lines= 7
cm_subsection = np.linspace(start, stop, number_of_lines) 

colors = [ cm.viridis(x) for x in cm_subsection ]

plt.plot(results_16[results_16['alpha']==50]['beta'][1:], results_16[results_16['alpha']==50]['error'][1:], color = colors[0], label = r'$\Delta x = 0.125m; \alpha = 50$')
plt.plot(results_16[results_16['alpha']==100]['beta'][1:], results_16[results_16['alpha']==100]['error'][1:], color = colors[1], label = r'$\Delta x = 0.125m; \alpha = 100$')
plt.plot(results_16[results_16['alpha']==150]['beta'][1:], results_16[results_16['alpha']==150]['error'][1:], color = colors[2], label = r'$\Delta x = 0.125m; \alpha = 150$')
plt.plot(results_16[results_16['alpha']==200]['beta'][1:], results_16[results_16['alpha']==200]['error'][1:], color = colors[3], label = r'$\Delta x = 0.125m; \alpha = 200$')
plt.plot(results_16[results_16['alpha']==250]['beta'][1:], results_16[results_16['alpha']==250]['error'][1:], color = colors[4], label = r'$\Delta x = 0.125m; \alpha = 250$')
plt.plot(results_16[results_16['alpha']==300]['beta'][1:], results_16[results_16['alpha']==300]['error'][1:], color = colors[5], label = r'$\Delta x = 0.125m; \alpha = 300$')
plt.plot(results_16[results_16['alpha']==350]['beta'][1:], results_16[results_16['alpha']==350]['error'][1:], color = colors[6], label = r'$\Delta x = 0.125m; \alpha = 350$')


plt.plot(results_08[results_08['alpha']==50]['beta'][1:], results_08[results_08['alpha']==50]['error'][1:], '--', color = colors[0], label = r'$\Delta x = 0.25m; \alpha = 50$')
plt.plot(results_08[results_08['alpha']==100]['beta'][1:], results_08[results_08['alpha']==100]['error'][1:],'--', color = colors[1], label = r'$\Delta x = 0.25m; \alpha = 100$')
plt.plot(results_08[results_08['alpha']==150]['beta'][1:], results_08[results_08['alpha']==150]['error'][1:], '--', color = colors[2], label = r'$\Delta x = 0.25m; \alpha = 150$')
plt.plot(results_08[results_08['alpha']==200]['beta'][1:], results_08[results_08['alpha']==200]['error'][1:], '--', color = colors[3], label = r'$\Delta x = 0.25m; \alpha = 200$')
plt.plot(results_08[results_08['alpha']==250]['beta'][1:], results_08[results_08['alpha']==250]['error'][1:], '--', color = colors[4], label = r'$\Delta x = 0.25m; \alpha = 250$')
plt.plot(results_08[results_08['alpha']==300]['beta'][1:], results_08[results_08['alpha']==300]['error'][1:], '--', color = colors[5], label = r'$\Delta x = 0.25m; \alpha = 300$')
plt.plot(results_08[results_08['alpha']==350]['beta'][1:], results_08[results_08['alpha']==350]['error'][1:], '--', color = colors[6], label = r'$\Delta x = 0.25m; \alpha = 350$')
plt.xlabel(r"$\beta$")
plt.ylabel("L2 error norm")
plt.legend(loc = 10, ncol =2)
plt.show()

plt.plot(results_04[results_04['alpha']==50]['beta'][1:], results_04[results_04['alpha']==50]['error'][1:], color = colors[0], label = r'$\Delta x = 0.5m; \alpha = 50$')
plt.plot(results_04[results_04['alpha']==100]['beta'][1:], results_04[results_04['alpha']==100]['error'][1:], color = colors[1], label = r'$\Delta x = 0.5m; \alpha = 100$')
plt.plot(results_04[results_04['alpha']==150]['beta'][1:], results_04[results_04['alpha']==150]['error'][1:], color = colors[2], label = r'$\Delta x = 0.5m; \alpha = 150$')
plt.plot(results_04[results_04['alpha']==200]['beta'][1:], results_04[results_04['alpha']==200]['error'][1:], color = colors[3], label = r'$\Delta x = 0.5m; \alpha = 200$')
plt.plot(results_04[results_04['alpha']==250]['beta'][1:], results_04[results_04['alpha']==250]['error'][1:], color = colors[4], label = r'$\Delta x = 0.5m; \alpha = 250$')
plt.plot(results_04[results_04['alpha']==300]['beta'][1:], results_04[results_04['alpha']==300]['error'][1:], color = colors[5], label = r'$\Delta x = 0.5m; \alpha = 300$')
plt.plot(results_04[results_04['alpha']==350]['beta'][1:], results_04[results_04['alpha']==350]['error'][1:], color = colors[6], label = r'$\Delta x = 0.5m; \alpha = 350$')
plt.xlabel(r"$\beta$")
plt.ylabel("L2 error norm")
plt.legend()
plt.show()

# %%
plt.plot(results_01[results_01['beta']==0]['alpha'], results_01[results_01['beta']==0]['error'], color = 'black', label = r'$\Delta x = 2m; \beta = 0$')
plt.plot(results_01[results_01['beta']==0.5]['alpha'], results_01[results_01['beta']==0.5]['error'], color = 'orange', label = r'$\Delta x = 2m; \beta = 0.5$')
plt.plot(results_01[results_01['beta']==1.0]['alpha'], results_01[results_01['beta']==1.0]['error'], color = 'red', label = r'$\Delta x = 2m; \beta = 1$')

plt.plot(results_02[results_02['beta']==0]['alpha'], results_02[results_02['beta']==0]['error'], '--', color = 'black', label = r'$\Delta x = 1m; \beta = 0$')
plt.plot(results_02[results_02['beta']==0.5]['alpha'], results_02[results_02['beta']==0.5]['error'], '--', color = 'orange', label = r'$\Delta x = 1m; \beta = 0.5$')
plt.plot(results_02[results_02['beta']==1.0]['alpha'], results_02[results_02['beta']==1.0]['error'], '--', color = 'red', label = r'$\Delta x = 1m; \beta = 1$')
plt.legend(loc = 10, ncol = 2)
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.show()

# %%
#plt.plot(results_01[results_01['beta']==0]['alpha'][1:], results_01[results_01['beta']==0]['error'][1:], label = '0')
plt.plot(results_02[results_02['beta']==0]['alpha'][1:], results_02[results_02['beta']==0]['error'][1:], label = '0')
plt.xlabel(r"$\alpha$")
plt.ylabel("L2 error norm")
plt.show()

# %%
fixed_mesh = pd.read_excel('results.xlsx', sheet_name = 'fixed')

xlist = []
xlist.append(fixed_mesh.iloc[0][0.100])
xlist.append(fixed_mesh.iloc[0][0.200])
xlist.append(fixed_mesh.iloc[0][0.400])
xlist.append(fixed_mesh.iloc[0][0.800])
xlist.append(fixed_mesh.iloc[0][1.600])

errorlist = []
errorlist.append(fixed_mesh.iloc[2][0.100])
errorlist.append(fixed_mesh.iloc[2][0.200])
errorlist.append(fixed_mesh.iloc[2][0.400])
errorlist.append(fixed_mesh.iloc[2][0.800])
errorlist.append(fixed_mesh.iloc[2][1.600])

# %%
plt.plot(xlist, errorlist, '-o')
plt.ylabel('L2 error norm')
plt.xlabel(r'$\Delta x$ (m)')
plt.show()

# %%
print(xlist)
# Out:
# [2.0, 1.0, 0.5, 0.25, 0.125]

# %%
logx = np.log(xlist)
log_error = np.log(errorlist)
poly = np.polyfit(logx, log_error, 1)
print(poly[0])
# Out:
# 1.1389850790907328
